# %% [markdown]
# # KELOMPOK 2
#
# ### Aido Luthfi Al Hakim	(2141720136)
# ### Evi Amalia Midfia		(2141720030)
# ### Muhammad Hatta		(2141720021)
# ### Tesya Eriana			(2141720024)

# %%
# Import library yang diperlukan

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import tensorflow
import keras

from tensorflow.keras.models import Sequential
from keras.layers import Dense, Dropout
from keras import regularizers
from keras.utils.vis_utils import plot_model

import warnings
warnings.filterwarnings('ignore')
#cuda 12.1 not recognized by tf :(
# %matplotlib inline
# print(tensorflow.__version__)

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# %%
# menampilkan data inputan (hidden input)

fig, ax = plt.subplots(nrows = 5, ncols = 10, figsize=(8,4), subplot_kw={'xticks': [], 'yticks': []})
for row in range(0,5):
    for col in range(0,10):
        myid = (10*row) + col # (ncols*rows) + cols
        
        ax[row,col].imshow( x_train[myid], cmap=plt.cm.binary ) # W,H,C
        ax[row,col].axis('off')

plt.suptitle("Gambar data MNIST", size=20, color="#6166B3")

plt.show()

# %%
print("bentuk data: ",x_train.shape)
print("nilai max data: ",x_train[0].max())
# Out:
# bentuk data:  (60000, 28, 28)
# nilai max data:  255

# %%
# ubah bentuk data dan skala pixel menjadi (n,w*h)
x_train = x_train.reshape(-1, 28*28)
x_train = x_train.astype('float32') / 255
# sama juga untuk x_test
x_test = x_test.reshape(-1, 28*28)
x_test = x_test.astype('float32') / 255

print("bentuk data setelah: ",x_train.shape)
print("nilai max data setelah: ",x_train[0].max())
# Out:
# bentuk data setelah:  (60000, 784)
# nilai max data setelah:  1.0

# %%
# ubah bentuk label menjadi kategorical untuk digunakan tensorflow nantinya
y_train = tensorflow.keras.utils.to_categorical(y_train , num_classes=10)
y_test = tensorflow.keras.utils.to_categorical(y_test , num_classes=10)

# %%
# pembuatan hidden layer
from tensorflow.keras.layers import MaxPooling2D,Conv2D,Input,Add,MaxPool2D,Flatten,AveragePooling2D,Dense,BatchNormalization,ZeroPadding2D,Activation,Concatenate,UpSampling2D
from tensorflow.keras.models import Model

nn_model = Sequential()
nn_model.add(Dense(35, input_dim=784, activation='relu'))
nn_model.add(Dropout(0.3))
nn_model.add(Dense(10, activation='softmax'))
print(nn_model)
plot_model(nn_model, to_file='model.png', show_shapes=True, show_layer_names=True)
# Out:
# <keras.engine.sequential.Sequential object at 0x7fad15c35580>

# %%
nn_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = nn_model.fit(x_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.5255 - accuracy: 0.8411
# Epoch 2/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3217 - accuracy: 0.9045
# Epoch 3/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2810 - accuracy: 0.9149
# Epoch 4/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2558 - accuracy: 0.9219
# Epoch 5/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2406 - accuracy: 0.9264
# Epoch 6/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2280 - accuracy: 0.9297
# Epoch 7/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2245 - accuracy: 0.9311
# Epoch 8/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2135 - accuracy: 0.9334
# Epoch 9/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2070 - accuracy: 0.9356
# Epoch 10/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2032 - accuracy: 0.9368
# Epoch 11/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2032 - accuracy: 0.9366
# Epoch 12/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1965 - accuracy: 0.9392
# Epoch 13/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1926 - accuracy: 0.9395
# Epoch 14/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1873 - accuracy: 0.9408
# Epoch 15/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1878 - accuracy: 0.9405
# Epoch 16/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1870 - accuracy: 0.9402
# Epoch 17/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1803 - accuracy: 0.9431
# Epoch 18/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1797 - accuracy: 0.9420
# Epoch 19/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1781 - accuracy: 0.9438
# Epoch 20/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1791 - accuracy: 0.9433
# Epoch 21/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1764 - accuracy: 0.9431
# Epoch 22/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1726 - accuracy: 0.9445
# Epoch 23/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1699 - accuracy: 0.9456
# Epoch 24/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1704 - accuracy: 0.9464
# Epoch 25/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1663 - accuracy: 0.9462
# Epoch 26/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1679 - accuracy: 0.9464
# Epoch 27/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1656 - accuracy: 0.9469
# Epoch 28/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1644 - accuracy: 0.9467
# Epoch 29/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1662 - accuracy: 0.9461
# Epoch 30/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1634 - accuracy: 0.9469
# Epoch 31/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1617 - accuracy: 0.9478
# Epoch 32/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1599 - accuracy: 0.9480
# Epoch 33/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1585 - accuracy: 0.9490
# Epoch 34/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1593 - accuracy: 0.9481
# Epoch 35/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1585 - accuracy: 0.9494
# Epoch 36/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1565 - accuracy: 0.9491
# Epoch 37/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1592 - accuracy: 0.9484
# Epoch 38/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1594 - accuracy: 0.9485
# Epoch 39/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1553 - accuracy: 0.9497
# Epoch 40/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1515 - accuracy: 0.9509
# Epoch 41/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1546 - accuracy: 0.9499
# Epoch 42/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1560 - accuracy: 0.9491
# Epoch 43/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1498 - accuracy: 0.9512
# Epoch 44/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1548 - accuracy: 0.9492
# Epoch 45/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1493 - accuracy: 0.9506
# Epoch 46/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1489 - accuracy: 0.9511
# Epoch 47/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1488 - accuracy: 0.9513
# Epoch 48/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1535 - accuracy: 0.9504
# Epoch 49/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1475 - accuracy: 0.9516
# Epoch 50/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1484 - accuracy: 0.9516
# Epoch 51/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1489 - accuracy: 0.9506
# Epoch 52/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1470 - accuracy: 0.9522
# Epoch 53/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1482 - accuracy: 0.9511
# Epoch 54/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1479 - accuracy: 0.9511
# Epoch 55/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1450 - accuracy: 0.9522
# Epoch 56/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1459 - accuracy: 0.9511
# Epoch 57/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1449 - accuracy: 0.9523
# Epoch 58/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1428 - accuracy: 0.9517
# Epoch 59/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1428 - accuracy: 0.9525
# Epoch 60/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1442 - accuracy: 0.9520
# Epoch 61/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1416 - accuracy: 0.9530
# Epoch 62/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1442 - accuracy: 0.9523
# Epoch 63/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1444 - accuracy: 0.9528
# Epoch 64/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1410 - accuracy: 0.9533
# Epoch 65/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1404 - accuracy: 0.9542
# Epoch 66/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1421 - accuracy: 0.9531
# Epoch 67/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1424 - accuracy: 0.9531
# Epoch 68/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1406 - accuracy: 0.9534
# Epoch 69/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1391 - accuracy: 0.9537
# Epoch 70/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1416 - accuracy: 0.9536
# Epoch 71/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1397 - accuracy: 0.9530
# Epoch 72/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1360 - accuracy: 0.9555
# Epoch 73/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1391 - accuracy: 0.9543
# Epoch 74/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1380 - accuracy: 0.9543
# Epoch 75/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1409 - accuracy: 0.9522
# Epoch 76/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1399 - accuracy: 0.9535
# Epoch 77/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1380 - accuracy: 0.9540
# Epoch 78/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1390 - accuracy: 0.9538
# Epoch 79/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1377 - accuracy: 0.9545
# Epoch 80/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1382 - accuracy: 0.9542
# Epoch 81/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1393 - accuracy: 0.9540
# Epoch 82/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1374 - accuracy: 0.9539
# Epoch 83/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1352 - accuracy: 0.9552
# Epoch 84/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1350 - accuracy: 0.9548
# Epoch 85/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1357 - accuracy: 0.9549
# Epoch 86/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1371 - accuracy: 0.9549
# Epoch 87/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1345 - accuracy: 0.9562
# Epoch 88/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1367 - accuracy: 0.9540
# Epoch 89/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1338 - accuracy: 0.9551
# Epoch 90/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1340 - accuracy: 0.9555
# Epoch 91/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1345 - accuracy: 0.9552
# Epoch 92/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1329 - accuracy: 0.9558
# Epoch 93/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1344 - accuracy: 0.9548
# Epoch 94/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1338 - accuracy: 0.9558
# Epoch 95/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1328 - accuracy: 0.9559
# Epoch 96/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1341 - accuracy: 0.9550
# Epoch 97/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1318 - accuracy: 0.9557
# Epoch 98/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1338 - accuracy: 0.9551
# Epoch 99/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1340 - accuracy: 0.9555
# Epoch 100/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1323 - accuracy: 0.9550

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(12,4))
ax[0].plot(history.history['accuracy'])
ax[0].set_ylabel('Loss', fontsize=16)


ax[1].plot(history.history['loss'])
ax[1].set_ylabel('Acc', fontsize=16)
# Out:
# Text(0, 0.5, 'Acc')

# %%
y_prob = nn_model.predict(x_test)
y_pred = y_prob.argmax(axis=1)
y_test = np.argmax(y_test, axis=1)
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.9647

# %%
from sklearn.metrics import confusion_matrix  # for evaluating results
confusion_array = confusion_matrix(y_true = y_test,y_pred = y_pred)
confusion_array
# Out:
# array([[ 968,    0,    2,    1,    0,    2,    4,    1,    2,    0],
#        [   0, 1110,    5,    4,    0,    0,    3,    2,   11,    0],
#        [   2,    2,  996,    7,    3,    0,    2,    9,   11,    0],
#        [   0,    0,    6,  981,    0,   10,    0,    5,    6,    2],
#        [   0,    1,    7,    0,  927,    0,    9,    5,    5,   28],
#        [   2,    0,    2,   11,    0,  861,    4,    1,    7,    4],
#        [  12,    3,    2,    0,    5,   12,  919,    0,    4,    1],
#        [   2,    8,    9,    7,    4,    1,    0,  991,    0,    6],
#        [   6,    3,    5,    4,    3,   12,    2,    6,  930,    3],
#        [   5,    4,    0,   10,   13,    7,    0,    4,    2,  964]])

# %%
import pandas as pd
import seaborn as sn
df_cm = pd.DataFrame(confusion_array, range(10), range(10))
plt.figure(figsize=(10,7))
sn.set(font_scale=1.4) # for label size
sn.heatmap(df_cm, annot=True, annot_kws={"size": 10}) # font size
# Out:
# <Axes: >

# %% [markdown]
# # Model dengan konfigurasi lain

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
# ubah bentuk data dan skala pixel menjadi (n,w*h)
x_train = x_train.reshape(-1, 28*28)
x_train = x_train.astype('float32') / 255
# sama juga untuk x_test
x_test = x_test.reshape(-1, 28*28)
x_test = x_test.astype('float32') / 255

print("bentuk data setelah: ",x_train.shape)
print("nilai max data setelah: ",x_train[0].max())
# Out:
# bentuk data setelah:  (60000, 784)
# nilai max data setelah:  1.0

# %%
# ubah bentuk data dan skala pixel menjadi (n,w*h)
x_train = x_train.reshape(-1, 28*28)
x_train = x_train.astype('float32') / 255
# sama juga untuk x_test
x_test = x_test.reshape(-1, 28*28)
x_test = x_test.astype('float32') / 255

print("bentuk data setelah: ",x_train.shape)
print("nilai max data setelah: ",x_train[0].max())
# Out:
# bentuk data setelah:  (60000, 784)
# nilai max data setelah:  0.003921569

# %%
# ubah bentuk label menjadi kategorical untuk digunakan tensorflow nantinya
y_train = tensorflow.keras.utils.to_categorical(y_train , num_classes=10)
y_test = tensorflow.keras.utils.to_categorical(y_test , num_classes=10)

# %%
nn_model = Sequential()
nn_model.add(Dense(35, input_dim=784, activation='relu'))
nn_model.add(Dropout(0.3))
nn_model.add(Dense(21, activation='relu'))
nn_model.add(Dense(10, activation='softmax'))

nn_model.summary()

plot_model(nn_model, to_file='model.png', show_shapes=True, show_layer_names=True)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_16 (Dense)            (None, 35)                27475
#
#  dropout_6 (Dropout)         (None, 35)                0
#
#  dense_17 (Dense)            (None, 21)                756
#
#  dense_18 (Dense)            (None, 10)                220
#
# =================================================================
# Total params: 28,451
# Trainable params: 28,451
# Non-trainable params: 0
# _________________________________________________________________

# %%
nn_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = nn_model.fit(x_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 1.3583 - accuracy: 0.5433
# Epoch 2/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.7767 - accuracy: 0.7439
# Epoch 3/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.6364 - accuracy: 0.7957
# Epoch 4/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5593 - accuracy: 0.8242
# Epoch 5/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5165 - accuracy: 0.8362
# Epoch 6/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4916 - accuracy: 0.8459
# Epoch 7/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4676 - accuracy: 0.8530
# Epoch 8/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4559 - accuracy: 0.8565
# Epoch 9/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4430 - accuracy: 0.8612
# Epoch 10/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4315 - accuracy: 0.8635
# Epoch 11/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4243 - accuracy: 0.8677
# Epoch 12/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4166 - accuracy: 0.8685
# Epoch 13/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4042 - accuracy: 0.8735
# Epoch 14/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.3984 - accuracy: 0.8766
# Epoch 15/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3960 - accuracy: 0.8755
# Epoch 16/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3887 - accuracy: 0.8789
# Epoch 17/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3858 - accuracy: 0.8780
# Epoch 18/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3775 - accuracy: 0.8815
# Epoch 19/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3772 - accuracy: 0.8810
# Epoch 20/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3729 - accuracy: 0.8821
# Epoch 21/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3669 - accuracy: 0.8855
# Epoch 22/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3666 - accuracy: 0.8833
# Epoch 23/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.3642 - accuracy: 0.8859
# Epoch 24/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3580 - accuracy: 0.8867
# Epoch 25/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3551 - accuracy: 0.8881
# Epoch 26/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3491 - accuracy: 0.8872
# Epoch 27/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3497 - accuracy: 0.8900
# Epoch 28/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3436 - accuracy: 0.8909
# Epoch 29/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.3408 - accuracy: 0.8901
# Epoch 30/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3407 - accuracy: 0.8916
# Epoch 31/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3407 - accuracy: 0.8924
# Epoch 32/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3386 - accuracy: 0.8929
# Epoch 33/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3394 - accuracy: 0.8934
# Epoch 34/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3325 - accuracy: 0.8946
# Epoch 35/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3329 - accuracy: 0.8929
# Epoch 36/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3314 - accuracy: 0.8954
# Epoch 37/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3269 - accuracy: 0.8962
# Epoch 38/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3283 - accuracy: 0.8958
# Epoch 39/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3256 - accuracy: 0.8971
# Epoch 40/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3265 - accuracy: 0.8973
# Epoch 41/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3197 - accuracy: 0.8988
# Epoch 42/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3189 - accuracy: 0.8985
# Epoch 43/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3186 - accuracy: 0.8989
# Epoch 44/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3202 - accuracy: 0.8990
# Epoch 45/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3157 - accuracy: 0.8999
# Epoch 46/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3147 - accuracy: 0.8998
# Epoch 47/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3116 - accuracy: 0.9016
# Epoch 48/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3155 - accuracy: 0.8987
# Epoch 49/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3096 - accuracy: 0.9017
# Epoch 50/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3127 - accuracy: 0.9006
# Epoch 51/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3110 - accuracy: 0.9013
# Epoch 52/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3091 - accuracy: 0.9003
# Epoch 53/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3086 - accuracy: 0.9021
# Epoch 54/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3083 - accuracy: 0.9019
# Epoch 55/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3066 - accuracy: 0.9017
# Epoch 56/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3072 - accuracy: 0.9017
# Epoch 57/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3020 - accuracy: 0.9027
# Epoch 58/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3057 - accuracy: 0.9027
# Epoch 59/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3016 - accuracy: 0.9043
# Epoch 60/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2997 - accuracy: 0.9048
# Epoch 61/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3006 - accuracy: 0.9043
# Epoch 62/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2993 - accuracy: 0.9056
# Epoch 63/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2976 - accuracy: 0.9050
# Epoch 64/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2961 - accuracy: 0.9058
# Epoch 65/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2989 - accuracy: 0.9050
# Epoch 66/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2994 - accuracy: 0.9043
# Epoch 67/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2957 - accuracy: 0.9053
# Epoch 68/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2951 - accuracy: 0.9063
# Epoch 69/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2953 - accuracy: 0.9064
# Epoch 70/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2927 - accuracy: 0.9058
# Epoch 71/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2898 - accuracy: 0.9079
# Epoch 72/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2910 - accuracy: 0.9069
# Epoch 73/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2875 - accuracy: 0.9082
# Epoch 74/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2906 - accuracy: 0.9083
# Epoch 75/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2885 - accuracy: 0.9079
# Epoch 76/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2909 - accuracy: 0.9074
# Epoch 77/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2920 - accuracy: 0.9076
# Epoch 78/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2898 - accuracy: 0.9065
# Epoch 79/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2899 - accuracy: 0.9071
# Epoch 80/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2866 - accuracy: 0.9087
# Epoch 81/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2860 - accuracy: 0.9079
# Epoch 82/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2845 - accuracy: 0.9086
# Epoch 83/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2845 - accuracy: 0.9078
# Epoch 84/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2863 - accuracy: 0.9081
# Epoch 85/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2856 - accuracy: 0.9093
# Epoch 86/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2806 - accuracy: 0.9094
# Epoch 87/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2839 - accuracy: 0.9096
# Epoch 88/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2833 - accuracy: 0.9089
# Epoch 89/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2833 - accuracy: 0.9092
# Epoch 90/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2852 - accuracy: 0.9086
# Epoch 91/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2801 - accuracy: 0.9111
# Epoch 92/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2810 - accuracy: 0.9099
# Epoch 93/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2817 - accuracy: 0.9099
# Epoch 94/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2825 - accuracy: 0.9089
# Epoch 95/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2797 - accuracy: 0.9112
# Epoch 96/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2797 - accuracy: 0.9094
# Epoch 97/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2814 - accuracy: 0.9091
# Epoch 98/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2761 - accuracy: 0.9111
# Epoch 99/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2787 - accuracy: 0.9109
# Epoch 100/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2799 - accuracy: 0.9101

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(12,4))
ax[0].plot(history.history['accuracy'])
ax[0].set_ylabel('Loss', fontsize=16)


ax[1].plot(history.history['loss'])
ax[1].set_ylabel('Acc', fontsize=16)
# Out:
# Text(0, 0.5, 'Acc')

# %%
y_prob = nn_model.predict(x_test)
y_pred = y_prob.argmax(axis=1)
y_test = np.argmax(y_test, axis=1)
accuracy_score(y_test,y_pred)
# Out:
# 0.9502

# %%
confusion_array = confusion_matrix(y_true = y_test,y_pred = y_pred)
confusion_array
# Out:
# array([[ 965,    0,    2,    1,    0,    3,    7,    1,    1,    0],
#        [   0, 1101,    2,    4,    1,    3,    6,    2,   16,    0],
#        [   7,    2,  991,    7,    2,    2,    5,    7,    9,    0],
#        [   2,    1,   18,  947,    0,   24,    1,    8,    9,    0],
#        [   1,    0,    4,    0,  934,    0,   10,    1,    2,   30],
#        [  11,    0,    2,   27,    4,  808,   12,    2,   23,    3],
#        [  14,    3,    2,    0,    5,    5,  924,    0,    5,    0],
#        [   2,   11,   19,    6,    5,    0,    0,  962,    4,   19],
#        [   6,    2,    6,    5,    5,   10,    9,    9,  919,    3],
#        [   5,    4,    1,    8,   16,   12,    0,    8,    4,  951]])

# %%
df_cm = pd.DataFrame(confusion_array, range(10), range(10))
plt.figure(figsize=(10,7))
sn.set(font_scale=1.4) # for label size
sn.heatmap(df_cm, annot=True, annot_kws={"size": 10}) # font size
# Out:
# <Axes: >
